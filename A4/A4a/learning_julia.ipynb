# %%
foo = "schway"
println(foo)
println(typeof(foo))
# Out:
# schway
# String

# %%
# dot syntax for broadcasting

# %%
# Α α, Β β, Γ γ, Δ δ, Ε ε, Ζ ζ, Η η, Θ θ, Ι ι, Κ κ, Λ λ, Μ μ, Ν ν, Ξ ξ, Ο ο, Π π, Ρ ρ, Σ σ/ς, Τ τ, Υ υ, Φ φ, Χ χ, Ψ ψ, Ω ω

# %%
println(str)
# Out:
# Α α, Β β, Γ γ, Δ δ, Ε ε, Ζ ζ, Η η, Θ θ, Ι ι, Κ κ, Λ λ, Μ μ, Ν ν, Ξ ξ, Ο ο, Π π, Ρ ρ, Σ σ/ς, Τ τ, Υ υ, Φ φ, Χ χ, Ψ ψ, Ω ω

# %%
str = "Α α, Β β, Γ γ, Δ δ, Ε ε, Ζ ζ, Η η, Θ θ, Ι ι, Κ κ, Λ λ, Μ μ, Ν ν, Ξ ξ, Ο ο, Π π, Ρ ρ, Σ σ/ς, Τ τ, Υ υ, Φ φ, Χ χ, Ψ ψ, Ω ω"
str = replace(str, " " => "")
# Out:
# "Αα,Ββ,Γγ,Δδ,Εε,Ζζ,Ηη,Θθ,Ιι,Κκ,Λλ,Μμ,Νν,Ξξ,Οο,Ππ,Ρρ,Σσ/ς,Ττ,Υυ,Φφ,Χχ,Ψψ,Ωω"

# %%
println()

# %%
for i = 1:length([1,2,3,4])
    println(i)
end

# %%
# plot([f,g],begin,end)

# %%
# vector appending:
[[1,2,3,4];[5,6]]

# %%
# s, t = writetowav(t->harmonic(t; f1=10, Φlist=0.5); duration=0.1, filename="1b.wav", createfile=false, playfile=false);

# %%
# plot(t,s)

# %%
# transform = fft(s);

# %%
# plot(transform)

# %%
# plot(real(ifft(transform)))
